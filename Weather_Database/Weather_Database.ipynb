# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 758

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_cloudiness,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | winneba
# Processing Record 2 of Set 1 | ojinaga
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | talnakh
# Processing Record 5 of Set 1 | mutis
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | kollegal
# Processing Record 10 of Set 1 | kaitangata
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | saint-pierre
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | bhimunipatnam
# Processing Record 17 of Set 1 | kupang
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | marienburg
# Processing Record 20 of Set 1 | kailua
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | hambantota
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | along
# Processing Record 29 of Set 1 | creston
# Processing Record 30 of Set 1 | kysyl-syr
# Processing Record 31 of Set 1 | ulladulla
# Processing Record 32 of Set 1 | auki
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | toftir
# City not found. Skipping...
# Processing Record 35 of Set 1 | sitka
# Processing Record 36 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 1 | doembang nangbuat
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | geresk
# City not found. Skipping...
# Processing Record 40 of Set 1 | bathsheba
# Processing Record 41 of Set 1 | sao filipe
# Processing Record 42 of Set 1 | sakakah
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 1 | lagoa
# Processing Record 46 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | palmer
# Processing Record 49 of Set 1 | ternate
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | bahir dar
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | lavrentiya
# Processing Record 4 of Set 2 | mogok
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | esik
# Processing Record 7 of Set 2 | pangody
# Processing Record 8 of Set 2 | bradut
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | poya
# Processing Record 12 of Set 2 | knysna
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | dalbandin
# Processing Record 15 of Set 2 | port hardy
# Processing Record 16 of Set 2 | mahebourg
# Processing Record 17 of Set 2 | springbok
# Processing Record 18 of Set 2 | panaba
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | yerbogachen
# Processing Record 21 of Set 2 | port elizabeth
# Processing Record 22 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 2 | itaituba
# Processing Record 24 of Set 2 | guerrero negro
# Processing Record 25 of Set 2 | port blair
# Processing Record 26 of Set 2 | victoria
# Processing Record 27 of Set 2 | cabo san lucas
# Processing Record 28 of Set 2 | fort nelson
# Processing Record 29 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 2 | huarmey
# Processing Record 31 of Set 2 | porto santo
# Processing Record 32 of Set 2 | chokurdakh
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | kargasok
# Processing Record 35 of Set 2 | hami
# Processing Record 36 of Set 2 | khatanga
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | nome
# Processing Record 39 of Set 2 | daru
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | chernyshevskiy
# Processing Record 42 of Set 2 | tuatapere
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | bubaque
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 2 | cabedelo
# Processing Record 49 of Set 2 | nandyal
# Processing Record 50 of Set 2 | asau
# Processing Record 1 of Set 3 | portland
# Processing Record 2 of Set 3 | kingaroy
# Processing Record 3 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 3 | lethem
# Processing Record 5 of Set 3 | bambous virieux
# Processing Record 6 of Set 3 | loviisa
# Processing Record 7 of Set 3 | onverwacht
# Processing Record 8 of Set 3 | kaltan
# Processing Record 9 of Set 3 | adrar
# Processing Record 10 of Set 3 | olinda
# Processing Record 11 of Set 3 | constitucion
# Processing Record 12 of Set 3 | assare
# Processing Record 13 of Set 3 | rundu
# Processing Record 14 of Set 3 | cayenne
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | ust-kuyga
# Processing Record 17 of Set 3 | axim
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | frisco
# Processing Record 20 of Set 3 | harper
# Processing Record 21 of Set 3 | general pico
# Processing Record 22 of Set 3 | matinhos
# Processing Record 23 of Set 3 | dunedin
# Processing Record 24 of Set 3 | khuzdar
# Processing Record 25 of Set 3 | alofi
# Processing Record 26 of Set 3 | mayo
# Processing Record 27 of Set 3 | fortuna
# Processing Record 28 of Set 3 | sandakan
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | san patricio
# Processing Record 31 of Set 3 | omboue
# Processing Record 32 of Set 3 | bluff
# Processing Record 33 of Set 3 | severo-kurilsk
# Processing Record 34 of Set 3 | narrabri
# Processing Record 35 of Set 3 | hobyo
# Processing Record 36 of Set 3 | ilebo
# Processing Record 37 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 3 | puerto madryn
# Processing Record 39 of Set 3 | praya
# Processing Record 40 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 3 | tsuruga
# Processing Record 42 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 3 | flinders
# Processing Record 44 of Set 3 | saint anthony
# Processing Record 45 of Set 3 | sao joao da barra
# Processing Record 46 of Set 3 | breves
# Processing Record 47 of Set 3 | atar
# Processing Record 48 of Set 3 | hervey bay
# Processing Record 49 of Set 3 | port alfred
# Processing Record 50 of Set 3 | ancud
# Processing Record 1 of Set 4 | suratgarh
# Processing Record 2 of Set 4 | ormara
# Processing Record 3 of Set 4 | bambanglipuro
# Processing Record 4 of Set 4 | pitimbu
# Processing Record 5 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 4 | hasaki
# Processing Record 7 of Set 4 | berbera
# Processing Record 8 of Set 4 | te anau
# Processing Record 9 of Set 4 | mount gambier
# Processing Record 10 of Set 4 | olafsvik
# Processing Record 11 of Set 4 | ust-tsilma
# Processing Record 12 of Set 4 | kodiak
# Processing Record 13 of Set 4 | provideniya
# Processing Record 14 of Set 4 | caborca
# Processing Record 15 of Set 4 | torbay
# Processing Record 16 of Set 4 | beidao
# Processing Record 17 of Set 4 | arenillas
# Processing Record 18 of Set 4 | qostanay
# Processing Record 19 of Set 4 | chilca
# Processing Record 20 of Set 4 | duarte
# Processing Record 21 of Set 4 | deputatskiy
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | airai
# Processing Record 24 of Set 4 | klaksvik
# Processing Record 25 of Set 4 | elmadag
# Processing Record 26 of Set 4 | wanaka
# Processing Record 27 of Set 4 | sorland
# Processing Record 28 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 4 | storm lake
# Processing Record 30 of Set 4 | ranong
# Processing Record 31 of Set 4 | east london
# Processing Record 32 of Set 4 | grindavik
# Processing Record 33 of Set 4 | nanortalik
# Processing Record 34 of Set 4 | srednekolymsk
# Processing Record 35 of Set 4 | tual
# Processing Record 36 of Set 4 | muzquiz
# City not found. Skipping...
# Processing Record 37 of Set 4 | barahona
# Processing Record 38 of Set 4 | puerto ayora
# Processing Record 39 of Set 4 | gobabis
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | lugazi
# Processing Record 42 of Set 4 | college
# Processing Record 43 of Set 4 | charagua
# Processing Record 44 of Set 4 | moen
# Processing Record 45 of Set 4 | lorengau
# Processing Record 46 of Set 4 | golub-dobrzyn
# Processing Record 47 of Set 4 | praia da vitoria
# Processing Record 48 of Set 4 | ponta do sol
# Processing Record 49 of Set 4 | tiksi
# Processing Record 50 of Set 4 | san carlos
# Processing Record 1 of Set 5 | malakal
# Processing Record 2 of Set 5 | margate
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | san pedro
# Processing Record 5 of Set 5 | dingle
# Processing Record 6 of Set 5 | bredasdorp
# Processing Record 7 of Set 5 | nelson bay
# Processing Record 8 of Set 5 | plymouth
# Processing Record 9 of Set 5 | espanola
# Processing Record 10 of Set 5 | atuona
# Processing Record 11 of Set 5 | bogande
# Processing Record 12 of Set 5 | honningsvag
# Processing Record 13 of Set 5 | los llanos de aridane
# Processing Record 14 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 5 | koslan
# Processing Record 16 of Set 5 | sangar
# Processing Record 17 of Set 5 | dubti
# Processing Record 18 of Set 5 | pangai
# Processing Record 19 of Set 5 | vestmannaeyjar
# Processing Record 20 of Set 5 | porto novo
# Processing Record 21 of Set 5 | mezen
# Processing Record 22 of Set 5 | koshurnikovo
# Processing Record 23 of Set 5 | arraial do cabo
# Processing Record 24 of Set 5 | bria
# Processing Record 25 of Set 5 | buritizeiro
# Processing Record 26 of Set 5 | ambilobe
# Processing Record 27 of Set 5 | takoradi
# Processing Record 28 of Set 5 | boda
# Processing Record 29 of Set 5 | port moresby
# Processing Record 30 of Set 5 | caucaia
# Processing Record 31 of Set 5 | coloso
# Processing Record 32 of Set 5 | vadso
# Processing Record 33 of Set 5 | eyl
# Processing Record 34 of Set 5 | mandalgovi
# Processing Record 35 of Set 5 | ngaoundere
# Processing Record 36 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 37 of Set 5 | kloulklubed
# Processing Record 38 of Set 5 | thinadhoo
# Processing Record 39 of Set 5 | samarai
# Processing Record 40 of Set 5 | beringovskiy
# Processing Record 41 of Set 5 | kikwit
# Processing Record 42 of Set 5 | springdale
# Processing Record 43 of Set 5 | carstairs
# Processing Record 44 of Set 5 | bollnas
# Processing Record 45 of Set 5 | eldorado
# Processing Record 46 of Set 5 | tilichiki
# Processing Record 47 of Set 5 | goalpara
# Processing Record 48 of Set 5 | monrovia
# Processing Record 49 of Set 5 | acton
# Processing Record 50 of Set 5 | port hedland
# Processing Record 1 of Set 6 | touros
# Processing Record 2 of Set 6 | vila franca do campo
# Processing Record 3 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 6 | pisco
# Processing Record 5 of Set 6 | codrington
# Processing Record 6 of Set 6 | toulepleu
# City not found. Skipping...
# Processing Record 7 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 8 of Set 6 | port lincoln
# Processing Record 9 of Set 6 | diamantino
# Processing Record 10 of Set 6 | massakory
# Processing Record 11 of Set 6 | madimba
# Processing Record 12 of Set 6 | santa rosa
# Processing Record 13 of Set 6 | beloha
# Processing Record 14 of Set 6 | ambovombe
# Processing Record 15 of Set 6 | yangambi
# Processing Record 16 of Set 6 | kabinda
# Processing Record 17 of Set 6 | jamestown
# Processing Record 18 of Set 6 | chupa
# Processing Record 19 of Set 6 | amapa
# Processing Record 20 of Set 6 | vokhma
# Processing Record 21 of Set 6 | biltine
# Processing Record 22 of Set 6 | arman
# Processing Record 23 of Set 6 | cidreira
# Processing Record 24 of Set 6 | mutata
# Processing Record 25 of Set 6 | nishihara
# Processing Record 26 of Set 6 | teguldet
# Processing Record 27 of Set 6 | svetlogorsk
# Processing Record 28 of Set 6 | maralal
# Processing Record 29 of Set 6 | tabora
# Processing Record 30 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 6 | pierre
# Processing Record 32 of Set 6 | saskylakh
# Processing Record 33 of Set 6 | virginia beach
# Processing Record 34 of Set 6 | kalanguy
# Processing Record 35 of Set 6 | usinsk
# Processing Record 36 of Set 6 | flin flon
# Processing Record 37 of Set 6 | huangnihe
# Processing Record 38 of Set 6 | ewo
# Processing Record 39 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 40 of Set 6 | kozhevnikovo
# Processing Record 41 of Set 6 | aklavik
# Processing Record 42 of Set 6 | xique-xique
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | aripuana
# Processing Record 45 of Set 6 | richards bay
# Processing Record 46 of Set 6 | okato
# Processing Record 47 of Set 6 | baiao
# Processing Record 48 of Set 6 | avera
# Processing Record 49 of Set 6 | bowen
# Processing Record 50 of Set 6 | gongzhuling
# Processing Record 1 of Set 7 | tuktoyaktuk
# Processing Record 2 of Set 7 | ponta delgada
# Processing Record 3 of Set 7 | phonhong
# Processing Record 4 of Set 7 | uspenskaya
# Processing Record 5 of Set 7 | esperance
# Processing Record 6 of Set 7 | kangaatsiaq
# Processing Record 7 of Set 7 | bethel
# Processing Record 8 of Set 7 | nikolsk
# Processing Record 9 of Set 7 | buala
# Processing Record 10 of Set 7 | tambopata
# Processing Record 11 of Set 7 | muros
# Processing Record 12 of Set 7 | damghan
# Processing Record 13 of Set 7 | bandarbeyla
# Processing Record 14 of Set 7 | hamilton
# Processing Record 15 of Set 7 | salalah
# Processing Record 16 of Set 7 | coquimbo
# Processing Record 17 of Set 7 | bardiyah
# Processing Record 18 of Set 7 | mianwali
# Processing Record 19 of Set 7 | otjiwarongo
# Processing Record 20 of Set 7 | walvis bay
# Processing Record 21 of Set 7 | qaqortoq
# Processing Record 22 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 7 | seoul
# Processing Record 24 of Set 7 | gorkovskoye
# City not found. Skipping...
# Processing Record 25 of Set 7 | porto-vecchio
# Processing Record 26 of Set 7 | vao
# Processing Record 27 of Set 7 | stykkisholmur
# Processing Record 28 of Set 7 | nador
# Processing Record 29 of Set 7 | kichera
# Processing Record 30 of Set 7 | gornopravdinsk
# Processing Record 31 of Set 7 | ilulissat
# Processing Record 32 of Set 7 | san-pedro
# Processing Record 33 of Set 7 | lososina
# Processing Record 34 of Set 7 | karratha
# Processing Record 35 of Set 7 | pevek
# Processing Record 36 of Set 7 | bintulu
# Processing Record 37 of Set 7 | abu dhabi
# Processing Record 38 of Set 7 | yar-sale
# Processing Record 39 of Set 7 | faya
# Processing Record 40 of Set 7 | oum hadjer
# Processing Record 41 of Set 7 | sola
# Processing Record 42 of Set 7 | murgab
# Processing Record 43 of Set 7 | chippewa falls
# Processing Record 44 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 7 | nhulunbuy
# Processing Record 46 of Set 7 | ruwi
# Processing Record 47 of Set 7 | kudahuvadhoo
# Processing Record 48 of Set 7 | victor harbor
# Processing Record 49 of Set 7 | shache
# Processing Record 50 of Set 7 | korla
# Processing Record 1 of Set 8 | ola
# Processing Record 2 of Set 8 | san rafael
# Processing Record 3 of Set 8 | sri aman
# Processing Record 4 of Set 8 | dawson creek
# Processing Record 5 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 8 | krasnoselkup
# Processing Record 7 of Set 8 | prokudskoye
# Processing Record 8 of Set 8 | hindaun
# Processing Record 9 of Set 8 | uglegorsk
# Processing Record 10 of Set 8 | rawson
# Processing Record 11 of Set 8 | bengkulu
# Processing Record 12 of Set 8 | yatou
# Processing Record 13 of Set 8 | khatra
# Processing Record 14 of Set 8 | kaihua
# Processing Record 15 of Set 8 | darien
# Processing Record 16 of Set 8 | lahat
# Processing Record 17 of Set 8 | fare
# Processing Record 18 of Set 8 | la ronge
# Processing Record 19 of Set 8 | sorong
# Processing Record 20 of Set 8 | sur
# Processing Record 21 of Set 8 | udachnyy
# Processing Record 22 of Set 8 | ekhabi
# Processing Record 23 of Set 8 | kavieng
# Processing Record 24 of Set 8 | oranjemund
# Processing Record 25 of Set 8 | aalsmeer
# Processing Record 26 of Set 8 | waterloo
# Processing Record 27 of Set 8 | faanui
# Processing Record 28 of Set 8 | catamarca
# Processing Record 29 of Set 8 | belaya gora
# Processing Record 30 of Set 8 | severo-yeniseyskiy
# Processing Record 31 of Set 8 | arteaga
# Processing Record 32 of Set 8 | padang
# Processing Record 33 of Set 8 | linares
# Processing Record 34 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 8 | houston
# Processing Record 36 of Set 8 | tasiilaq
# Processing Record 37 of Set 8 | riachao
# Processing Record 38 of Set 8 | abha
# Processing Record 39 of Set 8 | egvekinot
# Processing Record 40 of Set 8 | magadi
# Processing Record 41 of Set 8 | tecoanapa
# Processing Record 42 of Set 8 | haines junction
# Processing Record 43 of Set 8 | san juan
# Processing Record 44 of Set 8 | tura
# Processing Record 45 of Set 8 | tateyama
# Processing Record 46 of Set 8 | natal
# Processing Record 47 of Set 8 | santa maria
# Processing Record 48 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 49 of Set 8 | palpa
# Processing Record 50 of Set 8 | arrecife
# Processing Record 1 of Set 9 | chapais
# Processing Record 2 of Set 9 | araouane
# Processing Record 3 of Set 9 | rondonopolis
# Processing Record 4 of Set 9 | san cristobal
# Processing Record 5 of Set 9 | muisne
# Processing Record 6 of Set 9 | vanimo
# Processing Record 7 of Set 9 | perry
# Processing Record 8 of Set 9 | tezu
# Processing Record 9 of Set 9 | zhaotong
# Processing Record 10 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 11 of Set 9 | chara
# Processing Record 12 of Set 9 | sioux lookout
# Processing Record 13 of Set 9 | geraldton
# Processing Record 14 of Set 9 | georgetown
# Processing Record 15 of Set 9 | redlands
# Processing Record 16 of Set 9 | baltay
# Processing Record 17 of Set 9 | coihaique
# Processing Record 18 of Set 9 | nikolayevka
# Processing Record 19 of Set 9 | dikson
# Processing Record 20 of Set 9 | tautira
# Processing Record 21 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 22 of Set 9 | santa elena
# Processing Record 23 of Set 9 | tumut
# Processing Record 24 of Set 9 | katsuura
# Processing Record 25 of Set 9 | kyaikto
# Processing Record 26 of Set 9 | simpang
# Processing Record 27 of Set 9 | vila do maio
# Processing Record 28 of Set 9 | cananeia
# Processing Record 29 of Set 9 | rio grande
# Processing Record 30 of Set 9 | brainerd
# Processing Record 31 of Set 9 | dedougou
# Processing Record 32 of Set 9 | namibe
# Processing Record 33 of Set 9 | bonthe
# Processing Record 34 of Set 9 | bani walid
# Processing Record 35 of Set 9 | bengkalis
# City not found. Skipping...
# Processing Record 36 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 9 | alugan
# Processing Record 38 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 39 of Set 9 | srivardhan
# Processing Record 40 of Set 9 | havoysund
# Processing Record 41 of Set 9 | goure
# Processing Record 42 of Set 9 | misratah
# Processing Record 43 of Set 9 | bull savanna
# Processing Record 44 of Set 9 | kardamas
# Processing Record 45 of Set 9 | brewster
# Processing Record 46 of Set 9 | mount isa
# Processing Record 47 of Set 9 | panguna
# Processing Record 48 of Set 9 | zhigansk
# Processing Record 49 of Set 9 | wattegama
# Processing Record 50 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 1 of Set 10 | chegutu
# Processing Record 2 of Set 10 | formosa
# Processing Record 3 of Set 10 | hastings
# Processing Record 4 of Set 10 | salekhard
# Processing Record 5 of Set 10 | kang
# Processing Record 6 of Set 10 | leuna
# Processing Record 7 of Set 10 | slave lake
# Processing Record 8 of Set 10 | west wendover
# Processing Record 9 of Set 10 | galle
# Processing Record 10 of Set 10 | kimberley
# Processing Record 11 of Set 10 | evensk
# Processing Record 12 of Set 10 | jinchang
# Processing Record 13 of Set 10 | torring
# Processing Record 14 of Set 10 | nueve de julio
# Processing Record 15 of Set 10 | kembe
# Processing Record 16 of Set 10 | adana
# Processing Record 17 of Set 10 | luena
# Processing Record 18 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 10 | neiafu
# Processing Record 20 of Set 10 | erenhot
# Processing Record 21 of Set 10 | tongliao
# Processing Record 22 of Set 10 | nyurba
# Processing Record 23 of Set 10 | gudur
# Processing Record 24 of Set 10 | ardesen
# Processing Record 25 of Set 10 | aswan
# Processing Record 26 of Set 10 | cockburn town
# Processing Record 27 of Set 10 | tucuman
# Processing Record 28 of Set 10 | verkhoyansk
# Processing Record 29 of Set 10 | vostok
# Processing Record 30 of Set 10 | tsiroanomandidy
# Processing Record 31 of Set 10 | phuket
# Processing Record 32 of Set 10 | taoudenni
# Processing Record 33 of Set 10 | port victoria
# Processing Record 34 of Set 10 | bjelovar
# Processing Record 35 of Set 10 | angoche
# Processing Record 36 of Set 10 | ngunguru
# Processing Record 37 of Set 10 | dubai
# Processing Record 38 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 10 | pinega
# Processing Record 40 of Set 10 | kurchum
# Processing Record 41 of Set 10 | kharp
# Processing Record 42 of Set 10 | caravelas
# Processing Record 43 of Set 10 | puerto escondido
# Processing Record 44 of Set 10 | shingu
# Processing Record 45 of Set 10 | iwaki
# Processing Record 46 of Set 10 | muzhi
# Processing Record 47 of Set 10 | sabha
# Processing Record 48 of Set 10 | acapulco
# Processing Record 49 of Set 10 | yashalta
# Processing Record 50 of Set 10 | basco
# Processing Record 1 of Set 11 | hualmay
# Processing Record 2 of Set 11 | puerto ayacucho
# Processing Record 3 of Set 11 | vanavara
# Processing Record 4 of Set 11 | sokolow podlaski
# Processing Record 5 of Set 11 | hillsboro
# Processing Record 6 of Set 11 | clarksdale
# Processing Record 7 of Set 11 | sao francisco do sul
# Processing Record 8 of Set 11 | trairi
# Processing Record 9 of Set 11 | pacific grove
# Processing Record 10 of Set 11 | san quintin
# Processing Record 11 of Set 11 | nurota
# Processing Record 12 of Set 11 | norrtalje
# Processing Record 13 of Set 11 | lucapa
# Processing Record 14 of Set 11 | kapuskasing
# Processing Record 15 of Set 11 | mujiayingzi
# Processing Record 16 of Set 11 | porbandar
# Processing Record 17 of Set 11 | shelburne
# Processing Record 18 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 11 | marawi
# Processing Record 20 of Set 11 | arkhangelsk
# Processing Record 21 of Set 11 | berezovyy
# Processing Record 22 of Set 11 | kushima
# Processing Record 23 of Set 11 | saint george
# Processing Record 24 of Set 11 | ordzhonikidze
# Processing Record 25 of Set 11 | yulara
# Processing Record 26 of Set 11 | port macquarie
# Processing Record 27 of Set 11 | marshall
# Processing Record 28 of Set 11 | neustrelitz
# Processing Record 29 of Set 11 | burica
# City not found. Skipping...
# Processing Record 30 of Set 11 | mehran
# Processing Record 31 of Set 11 | pathein
# Processing Record 32 of Set 11 | saint-francois
# Processing Record 33 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 11 | busayra
# Processing Record 35 of Set 11 | kidal
# Processing Record 36 of Set 11 | kirakira
# Processing Record 37 of Set 11 | wilmington
# Processing Record 38 of Set 11 | khandyga
# Processing Record 39 of Set 11 | muyezerskiy
# Processing Record 40 of Set 11 | pousat
# City not found. Skipping...
# Processing Record 41 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 11 | skovorodino
# Processing Record 43 of Set 11 | hohhot
# Processing Record 44 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 11 | zhezkazgan
# Processing Record 46 of Set 11 | araripe
# Processing Record 47 of Set 11 | laiyang
# Processing Record 48 of Set 11 | bahia blanca
# Processing Record 49 of Set 11 | westport
# Processing Record 50 of Set 11 | torbat-e jam
# Processing Record 1 of Set 12 | broome
# Processing Record 2 of Set 12 | bairnsdale
# Processing Record 3 of Set 12 | shevchenkove
# Processing Record 4 of Set 12 | quatre cocos
# Processing Record 5 of Set 12 | the valley
# Processing Record 6 of Set 12 | alice springs
# Processing Record 7 of Set 12 | krasnogvardeyskoye
# Processing Record 8 of Set 12 | saldanha
# Processing Record 9 of Set 12 | selikhino
# Processing Record 10 of Set 12 | juegang
# Processing Record 11 of Set 12 | minsk
# Processing Record 12 of Set 12 | san vicente
# Processing Record 13 of Set 12 | peniche
# Processing Record 14 of Set 12 | maroantsetra
# Processing Record 15 of Set 12 | saint-louis
# Processing Record 16 of Set 12 | linkou
# Processing Record 17 of Set 12 | leningradskiy
# Processing Record 18 of Set 12 | azul
# Processing Record 19 of Set 12 | tessalit
# Processing Record 20 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 21 of Set 12 | cordele
# Processing Record 22 of Set 12 | alta floresta
# Processing Record 23 of Set 12 | kruisfontein
# Processing Record 24 of Set 12 | roebourne
# Processing Record 25 of Set 12 | esmeraldas
# Processing Record 26 of Set 12 | xiongzhou
# Processing Record 27 of Set 12 | kavaratti
# Processing Record 28 of Set 12 | lazurne
# Processing Record 29 of Set 12 | isla mujeres
# Processing Record 30 of Set 12 | dong hoi
# Processing Record 31 of Set 12 | lodwar
# Processing Record 32 of Set 12 | abu kamal
# Processing Record 33 of Set 12 | jacareacanga
# Processing Record 34 of Set 12 | marktredwitz
# Processing Record 35 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 12 | jiexiu
# Processing Record 37 of Set 12 | kodar
# Processing Record 38 of Set 12 | fairbanks
# Processing Record 39 of Set 12 | matagami
# Processing Record 40 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 41 of Set 12 | jasper
# Processing Record 42 of Set 12 | magadan
# Processing Record 43 of Set 12 | pangnirtung
# Processing Record 44 of Set 12 | saint-joseph
# Processing Record 45 of Set 12 | ariquemes
# Processing Record 46 of Set 12 | carballo
# Processing Record 47 of Set 12 | rossosh
# Processing Record 48 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 12 | gambela
# Processing Record 50 of Set 12 | boulsa
# Processing Record 1 of Set 13 | canguaretama
# Processing Record 2 of Set 13 | ahipara
# Processing Record 3 of Set 13 | gigmoto
# Processing Record 4 of Set 13 | dukat
# Processing Record 5 of Set 13 | petropavl
# Processing Record 6 of Set 13 | namatanai
# Processing Record 7 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 8 of Set 13 | itaperucu
# Processing Record 9 of Set 13 | pringsewu
# Processing Record 10 of Set 13 | bay roberts
# Processing Record 11 of Set 13 | piacabucu
# Processing Record 12 of Set 13 | okha
# Processing Record 13 of Set 13 | patillas
# Processing Record 14 of Set 13 | umba
# Processing Record 15 of Set 13 | paita
# Processing Record 16 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 13 | seymchan
# Processing Record 19 of Set 13 | bayan
# Processing Record 20 of Set 13 | rexburg
# Processing Record 21 of Set 13 | cauquenes
# Processing Record 22 of Set 13 | tecalitlan
# Processing Record 23 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 13 | vestmanna
# Processing Record 25 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 26 of Set 13 | olds
# Processing Record 27 of Set 13 | hovd
# Processing Record 28 of Set 13 | gejiu
# Processing Record 29 of Set 13 | filingue
# Processing Record 30 of Set 13 | kachiry
# Processing Record 31 of Set 13 | smithers
# Processing Record 32 of Set 13 | naspur
# Processing Record 33 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 13 | rocha
# Processing Record 35 of Set 13 | poum
# Processing Record 36 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 13 | jishui
# Processing Record 38 of Set 13 | boali
# Processing Record 39 of Set 13 | jagdalpur
# Processing Record 40 of Set 13 | chitrakonda
# Processing Record 41 of Set 13 | andenes
# Processing Record 42 of Set 13 | canatlan
# Processing Record 43 of Set 13 | vung tau
# Processing Record 44 of Set 13 | mokhsogollokh
# Processing Record 45 of Set 13 | yuzawa
# Processing Record 46 of Set 13 | gizo
# Processing Record 47 of Set 13 | ilo
# Processing Record 48 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 13 | el castillo
# Processing Record 50 of Set 13 | alekseyevsk
# Processing Record 1 of Set 14 | key west
# Processing Record 2 of Set 14 | aleksandrovskiy zavod
# Processing Record 3 of Set 14 | goderich
# Processing Record 4 of Set 14 | esna
# Processing Record 5 of Set 14 | sembakung
# Processing Record 6 of Set 14 | fergus falls
# Processing Record 7 of Set 14 | acari
# Processing Record 8 of Set 14 | kijang
# Processing Record 9 of Set 14 | coari
# Processing Record 10 of Set 14 | nadadores
# Processing Record 11 of Set 14 | chitral
# Processing Record 12 of Set 14 | nampa
# Processing Record 13 of Set 14 | ler
# Processing Record 14 of Set 14 | oktyabrskiy
# Processing Record 15 of Set 14 | shihezi
# Processing Record 16 of Set 14 | amazar
# Processing Record 17 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 18 of Set 14 | longonjo
# Processing Record 19 of Set 14 | khasan
# Processing Record 20 of Set 14 | buin
# Processing Record 21 of Set 14 | tabou
# Processing Record 22 of Set 14 | sainte-marie
# Processing Record 23 of Set 14 | barmer
# Processing Record 24 of Set 14 | hof
# Processing Record 25 of Set 14 | tromso
# Processing Record 26 of Set 14 | rocky mountain house
# Processing Record 27 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 28 of Set 14 | zaidpur
# Processing Record 29 of Set 14 | gumdag
# Processing Record 30 of Set 14 | coahuayana
# Processing Record 31 of Set 14 | verkhnevilyuysk
# Processing Record 32 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 33 of Set 14 | tuy hoa
# Processing Record 34 of Set 14 | isangel
# Processing Record 35 of Set 14 | kemijarvi
# Processing Record 36 of Set 14 | cabra
# Processing Record 37 of Set 14 | honiara
# Processing Record 38 of Set 14 | zaraysk
# Processing Record 39 of Set 14 | umm kaddadah
# Processing Record 40 of Set 14 | el alto
# Processing Record 41 of Set 14 | iguape
# Processing Record 42 of Set 14 | calama
# Processing Record 43 of Set 14 | manokwari
# Processing Record 44 of Set 14 | tchollire
# Processing Record 45 of Set 14 | kaseda
# Processing Record 46 of Set 14 | bairiki
# Processing Record 47 of Set 14 | strezhevoy
# Processing Record 48 of Set 14 | oyan
# Processing Record 49 of Set 14 | luderitz
# Processing Record 50 of Set 14 | kamaishi
# Processing Record 1 of Set 15 | ocos
# Processing Record 2 of Set 15 | puerto baquerizo moreno
# Processing Record 3 of Set 15 | gorele
# Processing Record 4 of Set 15 | saint cloud
# Processing Record 5 of Set 15 | kahului
# Processing Record 6 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 15 | kualakapuas
# Processing Record 8 of Set 15 | kaffrine
# Processing Record 9 of Set 15 | addis zemen
# City not found. Skipping...
# Processing Record 10 of Set 15 | north platte
# Processing Record 11 of Set 15 | namwala
# Processing Record 12 of Set 15 | marmora
# Processing Record 13 of Set 15 | itarema
# Processing Record 14 of Set 15 | ikalamavony
# Processing Record 15 of Set 15 | novouralsk
# Processing Record 16 of Set 15 | kamenka
# Processing Record 17 of Set 15 | mishelevka
# Processing Record 18 of Set 15 | leh
# Processing Record 19 of Set 15 | gabu
# Processing Record 20 of Set 15 | laguna
# Processing Record 21 of Set 15 | lompoc
# Processing Record 22 of Set 15 | bisira
# Processing Record 23 of Set 15 | tondano
# Processing Record 24 of Set 15 | ferkessedougou
# Processing Record 25 of Set 15 | evanton
# Processing Record 26 of Set 15 | eyrarbakki
# Processing Record 27 of Set 15 | dera din panah
# City not found. Skipping...
# Processing Record 28 of Set 15 | iqaluit
# Processing Record 29 of Set 15 | ahuimanu
# Processing Record 30 of Set 15 | aasiaat
# Processing Record 31 of Set 15 | miracema do tocantins
# Processing Record 32 of Set 15 | kaeo
# Processing Record 33 of Set 15 | villarrica
# Processing Record 34 of Set 15 | ketchikan
# Processing Record 35 of Set 15 | kjopsvik
# Processing Record 36 of Set 15 | punta alta
# Processing Record 37 of Set 15 | shimoda
# Processing Record 38 of Set 15 | fremont
# Processing Record 39 of Set 15 | black river
# Processing Record 40 of Set 15 | arlit
# Processing Record 41 of Set 15 | akyab
# Processing Record 42 of Set 15 | pusad
# Processing Record 43 of Set 15 | batemans bay
# Processing Record 44 of Set 15 | bestobe
# Processing Record 45 of Set 15 | wasilla
# Processing Record 46 of Set 15 | broken hill
# Processing Record 47 of Set 15 | ekibastuz
# Processing Record 48 of Set 15 | mizdah
# Processing Record 49 of Set 15 | pundaguitan
# Processing Record 50 of Set 15 | tecpan
# Processing Record 1 of Set 16 | lieksa
# Processing Record 2 of Set 16 | tutoia
# Processing Record 3 of Set 16 | sambava
# Processing Record 4 of Set 16 | kraksaan
# Processing Record 5 of Set 16 | damaturu
# Processing Record 6 of Set 16 | mubi
# Processing Record 7 of Set 16 | callaway
# Processing Record 8 of Set 16 | buta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 695

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Winneba   5.3511   -0.6231     77.05        85          93
# 1       Ojinaga  29.5667 -104.4167     47.35        71         100
# 2  Punta Arenas -53.1500  -70.9167     46.51        66          40
# 3       Talnakh  69.4865   88.3972    -18.36        93          97
# 4         Mutis   6.2262  -77.4044     76.42        93         100
# 5        Avarua -21.2078 -159.7750     73.45        68          75
# 6      Cherskiy  68.7500  161.3000    -17.25        98         100
# 7     Busselton -33.6500  115.3333     74.77        38           0
# 8      Kollegal  12.1500   77.1167     72.66        56          99
# 9    Kaitangata -46.2817  169.8464     58.87        95         100
#
#    Wind Speed Country Current Description
# 0        5.82      GH     overcast clouds
# 1        3.44      MX     overcast clouds
# 2       14.97      CL    scattered clouds
# 3        2.93      RU     overcast clouds
# 4        7.23      CO          light rain
# 5       11.50      CK       broken clouds
# 6        6.13      RU     overcast clouds
# 7        9.73      AU           clear sky
# 8        3.22      IN     overcast clouds
# 9        5.26      NZ     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Winneba      GH   5.3511   -0.6231     77.05        85          93
# 1         Ojinaga      MX  29.5667 -104.4167     47.35        71         100
# 2    Punta Arenas      CL -53.1500  -70.9167     46.51        66          40
# 3         Talnakh      RU  69.4865   88.3972    -18.36        93          97
# 4           Mutis      CO   6.2262  -77.4044     76.42        93         100
# ..            ...     ...      ...       ...       ...       ...         ...
# 690      Kraksaan      ID  -7.7585  113.3962     85.41        67         100
# 691      Damaturu      NG  11.7470   11.9608     72.64        28           6
# 692          Mubi      NG  10.2676   13.2644     77.27        22           9
# 693      Callaway      US  30.1530  -85.5699     42.98        61         100
# 694          Buta      CD   2.7858   24.7300     82.29        59          24
#
#      Wind Speed Current Description
# 0          5.82     overcast clouds
# 1          3.44     overcast clouds
# 2         14.97    scattered clouds
# 3          2.93     overcast clouds
# 4          7.23          light rain
# ..          ...                 ...
# 690        3.96     overcast clouds
# 691       11.14           clear sky
# 692        4.85           clear sky
# 693       11.50     overcast clouds
# 694        2.19          few clouds
#
# [695 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
